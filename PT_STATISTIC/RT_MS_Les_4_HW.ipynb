# %% [markdown]
# #### Задание 1
# Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %%
def msm(a, b):
    mx = (a + b)/2
    dx = (b - a)**2/12
    print(f'Средне: {mx}, Дисперсия: {dx}')

res = msm(200, 800)
# Out:
# Средне: 500.0, дисперси: 30000.0

# %% [markdown]
# #### Задание 2
#
# О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2. Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5? Если да, найдите ее.

# %%
from math import sqrt
def msm(a, b):
    s2 = sqrt(a * 12) + b
    mx2 = (b + s2) / 2
    print(f'Правая граница: {round(s2, 3)}, Её средняя граница: {round(mx2, 3)}')

res = msm(0.2, 0.5)
# Out:
# Правая граница: 2.049, Её средняя граница: 1.275

# %% [markdown]
# #### Задание 3
#
# Непрерывная случайная величина X распределена нормально и задана плотностью распределения:
#
# $$f(x) = (1 / (4 * sqrt(2pi))) * (exp(-((x+2)*2) / 32))$$
#
# $$f(x) = \frac{1}{\sigma \sqrt{2 \pi}} e ^ {- \frac{(x - a)^2}{2 \sigma^2}},$$
#
# Найдите:
#
# $$M(X) = \frac{𝑎+𝑏}{2} $$
#
# $$D(X) = \frac{(b - a)^2}{12}$$
#
# $$std(X)\ (среднее\  квадратичное\ отклонение)$$
#
# из условия: $a = -2, \sigma = 4$
#
# так как: $a = M(X), \; \sigma^2 = D(X)$
#
# получаем: $M(X) = -2, D(X) = 16,\ std(X) = 2$

# %% [markdown]
# #### Задание 4
# Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# - больше 182 см
# - больше 190 см
# - от 166 см до 190 см
# - от 166 см до 182 см
# - от 158 см до 190 см
# - не выше 150 см или не ниже 190 см
# - не выше 150 см или не ниже 198 см
# - ниже 166 см.

# %%
Mx4, std = 174, 8
sgm1, sgm2, sgm3 = 68, 95.4, 99.72

# %%
# Больше 182см. - из 100% отнимем 1 сигму и поделим на 2, т.к. отклонение от Мx4 - 1 сигма (174 + 8 = 182) 
# делим на 2 т.к. интервал симметричный относительно Mx4
Px41 = (100 - sgm1) / 2
# больше 190см - из 100% отнимем 2 сигму и поделим на 2.Отклонение от mx4 - 2 сигма
Px42 = (100 - sgm2) / 2
# от 166 см до 190 см.Интервал несимметричный. 190 - это отклонение 2 сигма (в отдну сторону) 
# 160 - отклонение  1 сигма в противоположную, поэтому для подсчет
Px43 = sgm1 + ((sgm2 - sgm1) / 2 )
# от 166 см до 182 см - это одна сигма 1 сигма
Px44 = sgm1
# от 158 см до 190 см - 2 сигма
Px45 = sgm2
# не выше 150 см или не ниже 190 см
Px46 = (100 - sgm3) + ((sgm3 - sgm2) / 2)
# не выше 150 см или не ниже 198 см
Px47 = 100 - sgm3
# ниже 166 см
Px48 = (100 - sgm1) / 2

# %%
print (f'Больше 182 см: {Px41}')
print (f'Больше 190 см: {round(Px42, 2)}')
print (f'От 166 см до 190 см: {Px43}')
print (f'От 166 см до 182 см: {Px44}')
print (f'От 158 см до 190 см: {Px45}')
print (f'Не выше 150 см или не ниже 190 см: {round(Px46, 2)}')
print (f'Не выше 150 см или не ниже 196 см : {round(Px47, 2)}')
print (f'Ниже 166 см: {Px4_8}')
# Out:
# Больше 182 см: 16.0
# Больше 190 см: 2.3
# От 166 см до 190 см: 81.7
# От 166 см до 182 см: 68
# От 158 см до 190 см: 95.4
# Не выше 150 см или не ниже 190 см: 2.44
# Не выше 150 см или не ниже 196 см : 0.28
# Ниже 166 см: 16.0

# %%
Px411 = 1 - (1-(Px41/100))
Px422 = 1 - (1-(Px42/100))
Px433 = (1 - (Px42/100)) - Px411
Px444 = (1-(Px41/100)) - Px411
Px455 = (1 - (Px42/100)) - Px422 
Px466 = ((1- sgm3/100)/2) + (1 - (1-(Px42/100)))
Px477 = (1- sgm3/100)
Px488 = Px411
print('Px411 =:', round(Px411, 2))
print('Px422 =:', round(Px422, 2)) 
print('Px433 =:', round(Px433, 2))
print('Px444 =:', round(Px444, 2))
print('Px455 =:', round(Px455, 2))
print('Px466 =:', round(Px466, 4))
print('Px477 =:', round(Px477, 4))
print('Px488 =:', round(Px488, 2))
# Out:
# Px411 =: 0.16
# Px422 =: 0.02
# Px433 =: 0.82
# Px444 =: 0.68
# Px455 =: 0.95
# Px466 =: 0.0244
# Px477 =: 0.0028
# Px488 =: 0.16

# %% [markdown]
# #### Задание 5
# На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %%
def msm(a, b, c):
    stdx5 = sqrt(b)
    sigma = (c - a)/stdx5
    print(f'на +{sigma} сигмы')

data_5 = msm(178, 25, 190)
# Out:
# на +2.4 сигмы
